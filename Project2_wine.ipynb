# %%
#libraries used in dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')

# %%
#read csv file 
df1=pd.read_csv('winequality-red.csv')
df1
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df=pd.DataFrame(data=df1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns   # 12 columns present in dataset
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.head()  #give five dataset from the begining
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.tail()    #give five dataset from the ending
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
df.dtypes # data type of columns
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.shape # rows and columns
# Out:
# (1599, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
# fixed acidity           1599 non-null float64
# volatile acidity        1599 non-null float64
# citric acid             1599 non-null float64
# residual sugar          1599 non-null float64
# chlorides               1599 non-null float64
# free sulfur dioxide     1599 non-null float64
# total sulfur dioxide    1599 non-null float64
# density                 1599 non-null float64
# pH                      1599 non-null float64
# sulphates               1599 non-null float64
# alcohol                 1599 non-null float64
# quality                 1599 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.describe() #statistical description
              # std deviation should be in between 0-1 range
              #here 'free sulfur dioxide' and 'total sulfur dioxide' showing high variance
              # high and low variance of data means outlier will present in dataset
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.isnull().sum() #no null value present
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.isnull().any().any()   #checking the missing data
# Out:
# False

# %%
sns.heatmap(df.isnull())  #no null value present in graphics

# %%
df.quality.unique()  # values of quality present in dataset
                    #all wines with ratings 7 and above to be of very good quality
                    #wines with 5 and 6 to be of average quality, and wines less than 5 to be of insipid quality
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
#no of unique value present in each col
#The feature that has a maximum unique value is density.
#The feature that has a minimum unique value is quality.
for col in df.iloc[:,0:-1]:
    print("No. of unique values of {} : {}".format(col,df[col].nunique()))
# Out:
# No. of unique values of fixed acidity : 96
# No. of unique values of volatile acidity : 143
# No. of unique values of citric acid : 80
# No. of unique values of residual sugar : 91
# No. of unique values of chlorides : 153
# No. of unique values of free sulfur dioxide : 60
# No. of unique values of total sulfur dioxide : 144
# No. of unique values of density : 436
# No. of unique values of pH : 89
# No. of unique values of sulphates : 96
# No. of unique values of alcohol : 65

# %%
df.quality.value_counts() #there are 681 no. which contain wine quality 5 and so on...
                          # all values are float accept quality
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
dfcor=df.corr()  #check whether data is highly corrleated or not
dfcor
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
sns.heatmap(dfcor)  # dark color show data highly correlated

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=False) #annot false showing graph without data
                                               #dark color showing highly correlated data

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dfcor,cmap='Blues',annot=True) #annot true give value also
#observations
#density has a strong positive correlation with residual sugar, whereas it has a strong negative correlation with alcohol
#pH & fixed acidity has negative correlation
#density & fixed acidity has positive correlation
#citric acid & fixed acidity has positive correlation
#citric acid & volatile acidity has negative correlation
#free sulphur dioxide & total sulphur dioxide has positive correlation

# %%
#now make boxplot of all columns
#boxplot is used to find outlier present or not
collist=df.columns.values
ncol=12
nrows=10
plt.figure(figsize=(2*ncol,8*ncol))
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='blue',orient='v')
    plt.tight_layout()

# %%
#to check the distribution of skewness
plt.figure(figsize=(2*ncol,5*ncol))  
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.distplot(df[collist[i]])
    plt.tight_layout()

# %%
sns.pairplot(df)

# %%
#now remove outlier
z=np.abs(zscore(df))
z
# Out:
# array([[0.52835961, 0.96187667, 1.39147228, ..., 0.57920652, 0.96024611,
#         0.78782264],
#        [0.29854743, 1.96744245, 1.39147228, ..., 0.1289504 , 0.58477711,
#         0.78782264],
#        [0.29854743, 1.29706527, 1.18607043, ..., 0.04808883, 0.58477711,
#         0.78782264],
#        ...,
#        [1.1603431 , 0.09955388, 0.72391627, ..., 0.54204194, 0.54162988,
#         0.45084835],
#        [1.39015528, 0.65462046, 0.77526673, ..., 0.30598963, 0.20930812,
#         0.78782264],
#        [1.33270223, 1.21684919, 1.02199944, ..., 0.01092425, 0.54162988,
#         0.45084835]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
z[13][9]
# Out:
# 5.32210116796055

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df_new.shape #outlier removed
# Out:
# (1451, 12)

# %%
df.shape
# Out:
# (1599, 12)

# %%
sns.countplot(x='fixed acidity',data=df)

# %%
#countplot graph is generally for categorical data
#showing that how data is distributed
plt.figure(figsize=(2*ncol,5*ncol))  
for i in range(0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.countplot(df[collist[i]])   #few observations
                                    #“quality” has a high number of values in categories 5, 6 and 7
                                    #Only a few observations are there for the category 3

# %%
sns.swarmplot(data=df,x='quality')

# %%
sns.stripplot(data=df,x='quality')

# %%
sns.violinplot(data=df,x='quality')

# %%
df.skew()  #skewed columns are residual sugar,chlorides,free sulfur dioxide,total sulfur dioxide and sulphates
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %%
#removal of skewness using log method
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# fixed acidity           0.455743
# volatile acidity        0.270168
# citric acid             0.318337
# residual sugar          2.255076
# chlorides               5.071476
# free sulfur dioxide    -0.097399
# total sulfur dioxide   -0.035746
# density                 0.071288
# pH                      0.193683
# sulphates               1.610497
# alcohol                 0.677798
# quality                 0.217802
# dtype: float64

# %%
sns.barplot(x=df['quality'],y=df['residual sugar'],data=df)

# %%
sns.barplot(x=df['quality'],y=df['density'],data=df)

# %%
#now apply linear regression because 'quality' contain continuous data
x=df.iloc[:,0:11]
x                       #x is input
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          2.128232          0.530628         0.00        1.064711   0.073250
# 1          2.174752          0.631272         0.00        1.280934   0.093490
# 2          2.174752          0.565314         0.04        1.193922   0.088011
# 3          2.501436          0.246860         0.56        1.064711   0.072321
# 4          2.128232          0.530628         0.00        1.064711   0.073250
# ...             ...               ...          ...             ...        ...
# 1594       1.974081          0.470004         0.08        1.098612   0.086178
# 1595       1.931521          0.438255         0.10        1.163151   0.060154
# 1596       1.987874          0.412110         0.13        1.193922   0.073250
# 1597       1.931521          0.497740         0.12        1.098612   0.072321
# 1598       1.945910          0.270027         0.47        1.526056   0.064851
#
# ...

# %%
df_x=df.iloc[:,0:11]
df_x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          2.128232          0.530628         0.00        1.064711   0.073250
# 1          2.174752          0.631272         0.00        1.280934   0.093490
# 2          2.174752          0.565314         0.04        1.193922   0.088011
# 3          2.501436          0.246860         0.56        1.064711   0.072321
# 4          2.128232          0.530628         0.00        1.064711   0.073250
# ...             ...               ...          ...             ...        ...
# 1594       1.974081          0.470004         0.08        1.098612   0.086178
# 1595       1.931521          0.438255         0.10        1.163151   0.060154
# 1596       1.987874          0.412110         0.13        1.193922   0.073250
# 1597       1.931521          0.497740         0.12        1.098612   0.072321
# 1598       1.945910          0.270027         0.47        1.526056   0.064851
#
# ...

# %%
#'quality' column in y
y=df.iloc[:,-1].values
y
# Out:
# array([5, 5, 5, ..., 6, 5, 6], dtype=int64)

# %%
y.shape
# Out:
# (1599,)

# %%
#now making y in 2D 

y=y.reshape(-1,1)

# %%
y.shape
# Out:
# (1599, 1)

# %%
from sklearn.preprocessing import StandardScaler #scaling--ensure that all data in a dataset falls in the same range
sc = StandardScaler()
x = sc.fit_transform(df_x) #training the machine
x
# Out:
# array([[-0.49206951,  0.98751431, -1.39147228, ...,  1.28864292,
#         -0.60176716, -0.99166574],
#        [-0.23078609,  1.86351245, -1.39147228, ..., -0.7199333 ,
#          0.18912335, -0.57421133],
#        [-0.23078609,  1.28941633, -1.18607043, ..., -0.33117661,
#         -0.00317263, -0.57421133],
#        ...,
#        [-1.28039794, -0.04406793, -0.72391627, ...,  0.70550789,
#          0.6247813 ,  0.59120544],
#        [-1.59690876,  0.70125933, -0.77526673, ...,  1.6773996 ,
#          0.37801568, -0.1719405 ],
#        [-1.51609325, -1.28074974,  1.02199944, ...,  0.51112954,
#          0.06131178,  0.59120544]])

# %%
y=sc.fit_transform(y)
y
# Out:
# array([[-0.78782264],
#        [-0.78782264],
#        [-0.78782264],
#        ...,
#        [ 0.45084835],
#        [-0.78782264],
#        [ 0.45084835]])

# %%
#x=pd.DataFrame(x,columns=df_x.columns)
#x.skew()

# %%
#removal of skewness using log method
#for col in x.columns:
#    if x.skew().loc[col]>0.55:
#        x[col]=np.log1p(x[col])

# %%
#x.skew()

# %%
#x.isnull().sum()

# %%
#finding max r2_score at which random_state
# at 92 random_score----r2_score is max which is 43%
max_r_score=0
for r_state in range(42,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=r_state,test_size=0.20)
    lr=linear_model.LinearRegression()
    lr.fit(x_train,y_train)
    predlr=lr.predict(x_test)
    r2_scr=r2_score(y_test,predlr)
    print("r2_score corrosponding to random state :",r_state," is: ",r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print()
print("max r2 score corrosponding to:",final_r_state," is ",max_r_score)
# Out:
# r2_score corrosponding to random state : 42  is:  0.40670295430902814
# r2_score corrosponding to random state : 43  is:  0.3877419779487863
# r2_score corrosponding to random state : 44  is:  0.31302493037156165
# r2_score corrosponding to random state : 45  is:  0.3389112840734727
# r2_score corrosponding to random state : 46  is:  0.3108901980785169
# r2_score corrosponding to random state : 47  is:  0.33178249509208146
# r2_score corrosponding to random state : 48  is:  0.29867277759189215
# r2_score corrosponding to random state : 49  is:  0.379205911230883
# r2_score corrosponding to random state : 50  is:  0.3056633848255703
# r2_score corrosponding to random state : 51  is:  0.2776352792801766
# r2_score corrosponding to random state : 52  is:  0.3470772081567487
# r2_score corrosponding to random state : 53  is:  0.37929498470860845
# r2_score corrosponding to random state : 54  is:  0.34833421514330243
# r2_score corrosponding to random state : 55  is:  0.36860128938655845
# ...

# %%
#lets do the cross validation--- to check model is overfitting or underfitting
from sklearn.model_selection import cross_val_score
a_score=cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2")
a_score
# Out:
# array([0.153675  , 0.30557717, 0.35016052, 0.38225151, 0.27676794])

# %%
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring="r2").mean()
#r2_score is greater than the cross val score ---model can go for production level
#but we need to improve our model
# Out:
# 0.293686428060928

# %%
   #since max r2_score is coming around random state 92 so we will use that to create our final model
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=92,test_size=0.20)
lr=linear_model.LinearRegression()
lr.fit(x_train,y_train)
predlr=lr.predict(x_test)

# %%
#lets evaluate RMSE and r2 score using sklearn lib
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
print("r2 score is: ",r2_score(y_test,predlr))
print("RMSE is :",np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# r2 score is:  0.42287377035102236
# RMSE is : 0.6990989200077714

# %%
#apply ensemble technique to boost the result
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor(n_estimators=10,random_state=92)
rf.fit(x_train,y_train)
print(rf.score(x_train,y_train))
pred=rf.predict(x_test)
print(pred)
print("Mean r2 score for Random Forest Regressor: ",cross_val_score(rf,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for Random Forest Regressor :",cross_val_score(rf,x,y,cv=5,scoring="r2").std())
# Out:
# 0.8932674781393108
# [-0.04462004  0.07924706  0.20311416 -0.29235424 -0.78782264 -0.29235424
#   0.57471545  0.45084835 -0.66395554  0.82244965  1.56565225  1.19405095
#   0.45084835 -0.66395554 -0.54008844 -0.29235424  0.07924706 -1.15942394
#  -0.78782264  0.82244965 -0.29235424  1.31791805 -0.41622134 -0.66395554
#  -0.78782264 -0.54008844  0.20311416  0.32698126  0.57471545 -1.03555684
#   1.07018385  0.07924706 -0.78782264  0.82244965  0.20311416 -0.78782264
#  -0.54008844  0.57471545  0.45084835  0.07924706  0.20311416  0.94631675
#  -0.29235424  1.07018385 -0.66395554  0.20311416  0.07924706  1.68951935
#  -1.65489234 -0.04462004 -0.41622134  0.32698126  0.94631675 -0.78782264
#  -0.41622134 -0.54008844  0.20311416 -0.78782264 -0.66395554  0.32698126
#  -0.41622134 -0.29235424  0.57471545 -0.41622134 -1.03555684 -0.78782264
#   0.07924706 -0.54008844 -0.29235424 -0.41622134 -0.66395554  0.94631675
#   0.32698126  0.20311416  1.93725355  1.44178515 -0.78782264 -0.66395554
# ...

# %%
#now apply adaboost regressor
from sklearn.ensemble import AdaBoostRegressor
model=AdaBoostRegressor()
model.fit(x_train,y_train)
print(model.score(x_train,y_train))
abpred=model.predict(x_test)
print(abpred)
model.score(x_test,y_test)
print("Mean r2 score for AdaBoost Regressor: ",cross_val_score(model,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for AdaBoost Regressor :",cross_val_score(model,x,y,cv=5,scoring="r2").std())
# Out:
# 0.4771843905377501
# [-0.29718023 -0.36614741  0.47507664 -0.57748228 -0.71726543  0.19321643
#   0.63148788  0.13667401 -0.55176943  0.42311691  0.40029036  0.81430815
#   0.40029036 -0.64113792 -0.41442617  0.06027642  0.13667401 -0.55176943
#  -0.64113792  0.42311691  0.54182419  1.32030011 -0.68460006 -0.96477564
#  -0.28196362 -1.48493515  0.60972137  0.40029036  0.83356593 -0.64113792
#   0.88208937 -0.10048888 -0.60629327  0.71229794  0.19321643 -0.36054589
#  -0.36549482  0.76911799  0.78077474 -0.36549482 -0.32661536  1.41373977
#   0.09451834  1.41373977 -0.28196362  0.81430815  0.19321643  1.33927445
#  -1.36109186 -0.50383466  0.41425126 -0.08558397  1.33418343 -0.36614741
#  -0.64113792 -0.42866461  0.58874727 -0.08558397 -0.36549482 -0.42866461
#  -0.36549482 -0.55176943  1.09758808 -0.36054589 -0.28196362 -0.36549482
#  -0.05870527 -0.36614741 -0.42866461 -0.47853025 -0.61731732  1.41373977
#  -0.0452363   0.63148788  1.41373977  0.83356593 -0.42866461 -0.45533727
# ...

# %%
#now we will use cross val score to check mean r2 score and std. deviation using GradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor
model=GradientBoostingRegressor()
model.fit(x_train,y_train)
model.score(x_test,y_test)
print("Mean r2 score for Gradient Boosting Regressor: ",cross_val_score(model,x,y,cv=5,scoring="r2").mean())
print("Standard deviation in r2 score for gradient boosting regressor :",cross_val_score(model,x,y,cv=5,scoring="r2").std())
# Out:
# Mean r2 score for Gradient Boosting Regressor:  0.3212120785520134
# Standard deviation in r2 score for gradient boosting regressor : 0.0539972532253793

# %%
from sklearn.externals import joblib
#save file as pickle
joblib.dump(lr,'winequality-red.pkl')
# Out:
# ['winequality-red.pkl']
